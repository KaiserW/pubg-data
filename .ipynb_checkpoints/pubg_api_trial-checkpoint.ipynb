# %%
my_key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJmYzA5N2YwMC0zMDFmLTAxMzYtMDdlZi0wYTU4NjQ3NTk1MDIiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTI1MjU2MjY3LCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImppemhpX2NoaWNrZW5fZWF0ZXIiLCJzY29wZSI6ImNvbW11bml0eSIsImxpbWl0IjoxMH0.jVXdVcA7eqXi1zwkqR8e8dWKtxYTNKweSx2wpjmfFvE'

# %%
import requests

url = 'https://api.playbattlegrounds.com/shards/pc-na/samples

header = {
  "Authorization": my_key,
  "Accept": "application/vnd.api+json"
}

response = requests.get(url, headers=header)

# %%
response
# Out:
# <Response [404]>

# %%
response.json()
# Out:
# {'data': {'type': 'sample',
#   'id': '3c55ab49-20af-4073-b7b8-75aeb9fc4890',
#   'attributes': {'shardId': 'pc-na',
#    'createdAt': '2018-05-01T23:59:12Z',
#    'titleId': 'bluehole-pubg'},
#   'relationships': {'matches': {'data': [{'type': 'match',
#       'id': 'fc156158-4187-4147-b7fd-0f724dc5230c'},
#      {'type': 'match', 'id': 'e18ae457-dfa6-4e4a-823d-1aeb0960a035'},
#      {'type': 'match', 'id': '1460d3bb-6856-4965-848e-d433f16a90ea'},
#      {'type': 'match', 'id': 'dc77fea6-4b70-4dea-8aca-146f6e4a1a9a'},
#      {'type': 'match', 'id': 'c6757196-fb5b-4a55-8c97-225b5484776d'},
#      {'type': 'match', 'id': 'e8d622d3-2bf8-4ec1-a494-1aa8e6ac7c6e'},
#      {'type': 'match', 'id': '05d7ee01-9920-4707-b0e5-de5ac6c7b7dc'},
#      {'type': 'match', 'id': '4c1b7ee0-95c0-40e7-96db-bd7a10ee3260'},
#      {'type': 'match', 'id': '2326526b-549b-488c-8e83-d2cd209f7cea'},
#      {'type': 'match', 'id': '4729830a-7036-46f3-b2ce-f3c8555cc880'},
# ...

# %%
'e18ae457-dfa6-4e4a-823d-1aeb0960a035'

# %% [markdown]
# # a sample match

# %%
url = 'https://api.playbattlegrounds.com/shards/pc-na/matches/e18ae457-dfa6-4e4a-823d-1aeb0960a035'

# %%
header = {
  "Authorization": my_key,
  "Accept": "application/vnd.api+json"
}

response = requests.get(url, headers=header)

# %%
match_results = response.json()

# %%
match_results
# Out:
# {'data': {'type': 'match',
#   'id': 'e18ae457-dfa6-4e4a-823d-1aeb0960a035',
#   'attributes': {'createdAt': '2018-04-30T23:26:42Z',
#    'duration': 1948,
#    'stats': None,
#    'gameMode': 'squad',
#    'titleId': 'bluehole-pubg',
#    'shardId': 'pc-na',
#    'tags': None,
#    'mapName': 'Desert_Main'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '629270a9-f018-4e1f-bccf-b7ad346813de'},
#      {'type': 'roster', 'id': 'cbf17c79-4bc2-449c-beaa-4c743fcf5669'},
#      {'type': 'roster', 'id': '0105c26b-99a0-4ef0-bef3-b186c842e950'},
#      {'type': 'roster', 'id': '6142cba4-3956-4d6a-95cc-b764ec04c8ed'},
#      {'type': 'roster', 'id': 'ad7cb24f-4b20-48e9-b5d5-81fc5d084a2b'},
#      {'type': 'roster', 'id': 'e0533ba8-083f-4f59-8a5a-2f4474ce484f'},
#      {'type': 'roster', 'id': '6715d2ee-29cb-4cf7-b3af-4108b75ef998'},
#      {'type': 'roster', 'id': '8a8dc388-86f5-41e2-b27f-e13e033a2925'},
# ...

# %%
match_results['included'][0]
# Out:
# {'type': 'participant',
#  'id': 'd191e19a-438a-479d-adb1-91d193093c69',
#  'attributes': {'stats': {'DBNOs': 2,
#    'assists': 2,
#    'boosts': 8,
#    'damageDealt': 683.222961,
#    'deathType': 'byplayer',
#    'headshotKills': 1,
#    'heals': 21,
#    'killPlace': 4,
#    'killPoints': 1161,
#    'killPointsDelta': 58.9431763,
#    'killStreaks': 0,
#    'kills': 4,
#    'lastKillPoints': 0,
#    'lastWinPoints': 0,
#    'longestKill': 50,
#    'mostDamage': 0,
#    'name': 'Suntao1',
#    'playerId': 'account.cb79261dd5ce4f43bb0c675f4e92599b',
#    'revives': 0,
#    'rideDistance': 4038.13062,
#    'roadKills': 0,
#    'teamKills': 0,
#    'timeSurvived': 1948,
#    'vehicleDestroys': 0,
#    'walkDistance': 3902.78979,
#    'weaponsAcquired': 0,
#    'winPlace': 2,
#    'winPoints': 1077,
#    'winPointsDelta': 63.6369362},
#   'actor': '',
#   'shardId': 'pc-na'}}

# %%
import json

# %%
with open('pubg_match_e18ae457-dfa6-4e4a-823d-1aeb0960a035.json', 'w') as f:
    json.dump(match_results['included'], f)

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
match_data = pd.read_json('pubg_match_e18ae457-dfa6-4e4a-823d-1aeb0960a035.json')

# %%
players_data = match_data[match_data['type'] == 'participant']['attributes']

# %%
players_data.index
# Out:
# Int64Index([  0,   1,   4,   5,   6,   7,   8,  11,  12,  13,  14,  16,  17,
#              18,  19,  20,  21,  22,  23,  25,  26,  27,  28,  30,  31,  32,
#              33,  35,  36,  38,  39,  40,  41,  42,  43,  44,  46,  47,  48,
#              50,  52,  54,  55,  56,  57,  58,  59,  60,  62,  63,  64,  65,
#              67,  68,  69,  70,  71,  72,  74,  75,  78,  79,  80,  82,  83,
#              84,  85,  87,  88,  90,  91,  94,  95,  97,  98,  99, 100, 102,
#             103, 105, 106, 107, 108, 109, 110, 112, 113, 114, 115, 116, 117,
#             118, 119, 122, 123, 124, 125, 127, 128, 129],
#            dtype='int64')

# %%
players_data_clean = pd.DataFrame()

# %%
for i,j in enumerate(players_data.index):
    players_data_clean[i] = pd.Series(players_data[j]['stats'])

# %%
players_data_clean.T
# Out:
#    DBNOs assists boosts damageDealt deathType headshotKills heals killPlace  \
# 0      2       2      8     683.223  byplayer             1    21         4
# 1      1       0      2      125.76  byplayer             0     0        71
# 2      2       0      3     242.582  byplayer             0    11        29
# 3      4       1      7     778.522     alive             0     5         3
# 4      3       1      5     623.979     alive             1     5         2
# 5      2       0      0         200  byplayer             2     0        19
# 6      0       0      1     7.87701  byplayer             0     9        43
# 7      0       0      0       95.76  byplayer             0     0        86
# 8      1       0      3     99.0141  byplayer             0     4        33
# 9      0       0      4     5.57512  byplayer             0     0        56
# 10     0       0      0     86.3089  byplayer             0     0        76
# ...

# %%
players_data_clean.T.to_csv('pubg_match_clean_e18ae457-dfa6-4e4a-823d-1aeb0960a035.csv')

# %% [markdown]
# # a player data

# %%
url = 'https://api.playbattlegrounds.com/shards/pc-na/players?filter[playerNames]=shroud'

# %%
import requests

header = {
  "Authorization": my_key,
  "Accept": "application/vnd.api+json"
}

response = requests.get(url, headers=header)

# %%
shroud_data = response.json()

# %%
shroud_matches = [i['id'] for i in shroud_data['data'][0]['relationships']['matches']['data']]

# %%
def crawl_matches(id_lst, df):
    
    url_match_base = 'https://api.playbattlegrounds.com/shards/pc-na/matches/'
    
    for i in id_lst[:1]:
        
        # Request match stats
        match_url = url_match_base + i
        #print(match_url)
        print("Getting match <{}>".format(i))
        response = requests.get(match_url, headers=header)
        time.sleep(6)
        
        # Find personal stats
        for p in response.json()['included']:
            if p['type'] == 'participant':
                if p['attributes']['stats']['playerId'] == shroud_id:
                    df[i] = pd.Series(p['attributes']['stats'])

# %%
len(shroud_matches)
# Out:
# 108

# %%
shroud_id = 'account.d50fdc18fcad49c691d38466bed6f8fd'

# %%
for p in res.json()['included']:
    if p['type'] == 'participant':
        if p['attributes']['stats']['playerId'] == shroud_id:
            print(p['attributes']['stats'])
# Out:
# {'DBNOs': 7, 'assists': 0, 'boosts': 3, 'damageDealt': 1137.94788, 'deathType': 'alive', 'headshotKills': 0, 'heals': 4, 'killPlace': 2, 'killPoints': 1126, 'killPointsDelta': 45.3298645, 'killStreaks': 0, 'kills': 8, 'lastKillPoints': 0, 'lastWinPoints': 0, 'longestKill': 86, 'mostDamage': 0, 'name': 'shroud', 'playerId': 'account.d50fdc18fcad49c691d38466bed6f8fd', 'revives': 0, 'rideDistance': 2509.29053, 'roadKills': 0, 'teamKills': 0, 'timeSurvived': 1840, 'vehicleDestroys': 1, 'walkDistance': 4604.582, 'weaponsAcquired': 0, 'winPlace': 1, 'winPoints': 1519, 'winPointsDelta': 5.03462744}

# %%
import time

# %%
import pandas as pd
shroud_data = pd.DataFrame()

# %%
res = crawl_matches(shroud_matches, shroud_data)
# Out:
# Getting match <e8065ab4-3321-40c1-b7f2-f332fdb382d8>
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# G:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# G:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1715         result = _lib.SSL_do_handshake(self._ssl)
# -> 1716         self._raise_ssl_error(self._ssl, result)
#    1717
#
# G:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1447                     if errno != 0:
# -> 1448                         raise SysCallError(errno, errorcode.get(errno))
#    1449                 raise SysCallError(-1, "Unexpected EOF")
#
# ...
